# %% [markdown]
# # AI Cartoon Video Converter - Colab Quick Start
#
# 1. Change runtime to GPU: Runtime → Change runtime type → GPU
# 2. Run all cells

# %%
# !git clone https://github.com/YOUR_USERNAME/AI_CARTOON_VIDEO_CONVERTER.git
# %cd AI_CARTOON_VIDEO_CONVERTER
# !bash install.sh

# %%
# !python run.py
